# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', None)

# %%
df=pd.read_excel('기간별_일평균_대기환경_정보_2017년.xlsx')
df1=pd.read_excel('기간별_일평균_대기환경_정보_2016년.xlsx')

# %%
df.head()
# Out:
#        측정일자  권역명  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0  20170101  도심권    중구         81          64    0.003         0.057
# 1  20170101  도심권   용산구         77          73    0.003         0.039
# 2  20170101  도심권   종로구         82          67    0.003         0.054
# 3  20170101  서북권  서대문구         91          50    0.008         0.039
# 4  20170101  서북권   은평구         70          46    0.005         0.042
#
#    일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0           1.0         0.005
# 1           1.1         0.005
# 2           1.0         0.004
# 3           0.8         0.005
# 4           0.7         0.006

# %%
df1.head()
# Out:
#        측정일자  권역명 측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0  20160101  동북권  광진구         85          64    0.004         0.046
# 1  20160101  동남권  강남구         73          44    0.006         0.047
# 2  20160101  서남권  강서구         66          38    0.005         0.048
# 3  20160101  서남권  구로구         56          41    0.007         0.038
# 4  20160101  동북권  성북구         71          45    0.005         0.056
#
#    일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0           0.9         0.006
# 1           0.8         0.006
# 2           0.9         0.006
# 3           1.1         0.007
# 4           1.3         0.007

# %%
del df['아황산가스농도(ppm)']

# %%
df.head()
# Out:
#        측정일자  권역명  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0  20170101  도심권    중구         81          64
# 1  20170101  도심권   용산구         77          73
# 2  20170101  도심권   종로구         82          67
# 3  20170101  서북권  서대문구         91          50
# 4  20170101  서북권   은평구         70          46

# %%
del df1['아황산가스농도(ppm)']

# %%
df1
# Out:
#           측정일자  권역명  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0     20160101  동북권   광진구         85          64
# 1     20160101  동남권   강남구         73          44
# 2     20160101  서남권   강서구         66          38
# 3     20160101  서남권   구로구         56          41
# 4     20160101  동북권   성북구         71          45
# 5     20160101  동북권   중랑구         66          41
# 6     20160101  동북권   강북구         77          52
# 7     20160101  동남권   서초구         76          42
# 8     20160101  서북권  서대문구         69          39
# 9     20160101  도심권    중구         61          35
# 10    20160101  서북권   마포구         59          49
# 11    20160101  도심권   용산구         59          46
# 12    20160101  동북권   성동구         77          39
# 13    20160101  서북권   은평구         58          35
# 14    20160101  동북권   노원구         68          49
# 15    20160101  동북권  동대문구         66          44
# 16    20160101  동남권   강동구         77          45
# 17    20160101  서남권  영등포구         80          40
# ...

# %%
df.isnull().sum()
# Out:
# 측정일자          0
# 권역명           0
# 측정소명          0
# 미세먼지(㎍/㎥)     0
# 초미세먼지(㎍/㎥)    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# 측정일자          0
# 권역명           0
# 측정소명          0
# 미세먼지(㎍/㎥)     0
# 초미세먼지(㎍/㎥)    0
# dtype: int64

# %%
df3=pd.concat([df1,df])

# %%
df3
# Out:
#           측정일자  권역명  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0     20160101  동북권   광진구         85          64
# 1     20160101  동남권   강남구         73          44
# 2     20160101  서남권   강서구         66          38
# 3     20160101  서남권   구로구         56          41
# 4     20160101  동북권   성북구         71          45
# 5     20160101  동북권   중랑구         66          41
# 6     20160101  동북권   강북구         77          52
# 7     20160101  동남권   서초구         76          42
# 8     20160101  서북권  서대문구         69          39
# 9     20160101  도심권    중구         61          35
# 10    20160101  서북권   마포구         59          49
# 11    20160101  도심권   용산구         59          46
# 12    20160101  동북권   성동구         77          39
# 13    20160101  서북권   은평구         58          35
# 14    20160101  동북권   노원구         68          49
# 15    20160101  동북권  동대문구         66          44
# 16    20160101  동남권   강동구         77          45
# 17    20160101  서남권  영등포구         80          40
# ...

# %%
df2=df3[(df3["측정소명"] == '중랑구')]

# %%
del df3['권역명']

# %%
df3.head()
# Out:
#        측정일자 측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0  20160101  광진구         85          64
# 1  20160101  강남구         73          44
# 2  20160101  강서구         66          38
# 3  20160101  구로구         56          41
# 4  20160101  성북구         71          45

# %%
df2=df3[(df3["측정소명"] == '서대문구')]

# %%
df2.head()
# Out:
#          측정일자  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 8    20160101  서대문구         69          39
# 43   20160102  서대문구         55          26
# 69   20160103  서대문구        109          53
# 76   20160104  서대문구         89          43
# 101  20160105  서대문구         37          17

# %%
df2.head()
# Out:
#          측정일자  측정소명  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 8    20160101  서대문구         69          39
# 43   20160102  서대문구         55          26
# 69   20160103  서대문구        109          53
# 76   20160104  서대문구         89          43
# 101  20160105  서대문구         37          17

# %%
df2.to_csv('서울시_미세먼지_2016_2017년.csv')

# %%
df2.to_excel('서울시_미세먼지_2016_2017년.xlsx')
